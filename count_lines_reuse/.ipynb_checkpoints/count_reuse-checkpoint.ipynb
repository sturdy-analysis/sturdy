# %%
import subprocess
import pandas
import io

pandas.options.mode.copy_on_write = True

result = subprocess.run(["cloc", "--include-lang=Scala", "--by-file", "--csv", "../"], capture_output=True)
cloc = pandas.read_csv(io.BytesIO(result.stdout))
cloc = cloc[["filename", "code"]]
cloc.drop(cloc.tail(1).index, inplace=True)

cloc
# Out:
#                                               filename  code
# 0    ../sturdy-wasm/swam/core/src/swam/traversal/Tr...  2700
# 1    ../sturdy-wasm/swam/text/src/swam/text/Resolve...  1232
# 2    ../sturdy-wasm/swam/core/src/swam/validation/S...  1197
# 3    ../sturdy-wasm/swam/core/src/swam/binary/InstC...  1028
# 4    ../sturdy-wasm/swam/core/src/swam/traversal/Tr...  1026
# ..                                                 ...   ...
# 503  ../sturdy-tip/src/main/scala/sturdy/language/t...     0
# 504  ../sturdy-tip/src/test/scala/sturdy/language/t...     0
# 505  ../sturdy-tip/src/test/scala/sturdy/language/t...     0
# 506  ../sturdy-tip/src/test/scala/sturdy/language/t...     0
# 507  ../sturdy-wasm/src/main/scala/sturdy/language/...     0
#
# [508 rows x 2 columns]

# %%
def sturdy_tip(re: str):
    return cloc.filename.str.contains('sturdy-tip/src/main/scala/sturdy/language/tip/'+re, regex= True, na=False)

def sturdy_wasm(re: str):
    return cloc.filename.str.contains('sturdy-wasm/src/main/scala/sturdy/language/wasm/'+re, regex= True, na=False)

def sturdy_apron(re: str):
    return cloc.filename.str.contains('sturdy-apron/src/main/scala/sturdy/'+re, regex= True, na=False)

def sturdy_core(re: str):
    return cloc.filename.str.contains('sturdy-core/src/main/scala/sturdy/'+re, regex= True, na=False)

def toTex(res):
    total_loc = res['code'].sum()
    print('\\def\\sumCode{'+str(res['code'].sum())+' loc\\xspace}')
    print('\\def\\sumReuse{'+str(res[res['reuse'] == True]['code'].sum())+' loc\\xspace}')
    print('\\def\\sumNoReuse{'+str(res[res['reuse'] == False]['code'].sum())+' loc\\xspace}')
    print('\\def\\sumLanguageIndependent{'+str(res[res['language-independent'] == True]['code'].sum())+' loc\\xspace}')
    print('\\def\\sumLanguageSpecific{'+str(res[res['language-independent'] == False]['code'].sum())+' loc\\xspace}')
    print('\\def\\sumLanguageIndependentReuse{'+str(res[(res['language-independent'] == True) & (res['reuse'] == True)]['code'].sum())+' loc\\xspace}')
    print('\\def\\sumLanguageIndependentNoReuse{'+str(res[(res['language-independent'] == True) & (res['reuse'] == False)]['code'].sum())+' loc\\xspace}')
    print('\\def\\sumLanguageSpecificReuse{'+str(res[(res['language-independent'] == False) & (res['reuse'] == True)]['code'].sum())+' loc\\xspace}')
    print('\\def\\sumLanguageSpecificNoReuse{'+str(res[(res['language-independent'] == False) & (res['reuse'] == False)]['code'].sum())+' loc\\xspace}')
    print('\\def\\sumReuseOrLanguageIndependent{'+str(res[(res['language-independent'] == True) | (res['reuse'] == True)]['code'].sum())+' loc\\xspace}')

    print('\\def\\percentCode{'+"{:.1f}".format(res['code'].sum()/total_loc*100)+'\\%\\xspace}')
    print('\\def\\percentReuse{'+"{:.1f}".format(res[res['reuse'] == True]['code'].sum()/total_loc*100)+'\\%\\xspace}')
    print('\\def\\percentNoReuse{'+"{:.1f}".format(res[res['reuse'] == False]['code'].sum()/total_loc*100)+'\\%\\xspace}')
    print('\\def\\percentLanguageIndependent{'+"{:.1f}".format(res[res['language-independent'] == True]['code'].sum()/total_loc*100)+'\\%\\xspace}')
    print('\\def\\percentLanguageSpecific{'+"{:.1f}".format(res[res['language-independent'] == False]['code'].sum()/total_loc*100)+'\\%\\xspace}')
    print('\\def\\percentLanguageIndependentReuse{'+"{:.1f}".format(res[(res['language-independent'] == True) & (res['reuse'] == True)]['code'].sum()/total_loc*100)+'\\%\\xspace}')
    print('\\def\\percentLanguageIndependentNoReuse{'+"{:.1f}".format(res[(res['language-independent'] == True) & (res['reuse'] == False)]['code'].sum()/total_loc*100)+'\\%\\xspace}')
    print('\\def\\percentLanguageSpecificReuse{'+"{:.1f}".format(res[(res['language-independent'] == False) & (res['reuse'] == True)]['code'].sum()/total_loc*100)+'\\%\\xspace}')
    print('\\def\\percentLanguageSpecificNoReuse{'+"{:.1f}".format(res[(res['language-independent'] == False) & (res['reuse'] == False)]['code'].sum()/total_loc*100)+'\\%\\xspace}')
    print('\\def\\percentReuseOrLanguageIndependent{'+"{:.1f}".format(res[(res['language-independent'] == True) | (res['reuse'] == True)]['code'].sum()/total_loc*100)+'\\%\\xspace}')

# %%
fixpoint_language_independent = cloc[
    sturdy_core('fix/Combinators.scala') |
    sturdy_core('fix/Contextual.scala') |
    sturdy_core('fix/Fixpoint.scala') |
    sturdy_core('fix/Stack.scala') |
    sturdy_core('fix/StackedStates.scala') |
    sturdy_core('fix/State.scala') |
    sturdy_core('fix/context/Sensitivity.scala') |
    sturdy_core('fix/iter/.*')
]

common = pandas.concat([fixpoint_language_independent, cloc[
    sturdy_core('data/.*') |
    sturdy_core('effect/Effect.*') |
    sturdy_core('effect/ComputationJoiner.scala') |
    sturdy_core('effect/TrySturdy.scala')
]])

# %%
### Tip

# Language-specific, reuse
tip1 = cloc[
    sturdy_tip('generic/') |
    sturdy_tip('Interpreter.scala') |
    sturdy_tip('abstractions/Functions.scala') |
    sturdy_tip('abstractions/Records.scala') |
    sturdy_tip('abstractions/Control.scala') |
    sturdy_tip('abstractions/Fix.scala')
]
tip1["language-independent"] = False
tip1["reuse"] = True


# Language-specific, no reuse
tip2 = cloc[
    sturdy_wasm('analyses/RelationalAnalysis.scala')
]
tip2["language-independent"] = False
tip2["reuse"] = False

# Language-independent, reuse
tip3 = pandas.concat([common, cloc[
    sturdy_core('effect/allocation/(Allocator|AAllocatorFromContext).scala') |
    sturdy_core('effect/callframe/(CallFrame|DecidableCallFrame).scala') |
    sturdy_core('effect/failure/(Failure|AFallible|CollectedFailures).scala') |
    sturdy_core('effect/print/(Print|PrintBound).scala') |
    sturdy_core('effect/userinput/(A)?UserInput.scala') |
    sturdy_core('values/booleans/(Lifted)?Boolean(Branching|Ops).scala') |
    sturdy_core('values/integer/(Lifted)?IntegerOps.scala') |
    sturdy_core('values/ordering/(Lifted)?(Ordering|Eq)Ops.scala') |
    sturdy_core('values/references/(AbstractAddr|AbstractReference|(Lifted)?ReferenceOps).scala') |
    sturdy_core('values/types/BaseType.scala') |
    sturdy_core('values/Join.scala') |
    sturdy_core('values/Topped.scala')
]])
tip3["language-independent"] = True
tip3["reuse"] = True

# Language-independent, no reuse
tip4 = cloc[
    sturdy_core('RecencyAddr.*') |
    sturdy_core('RecencyStore.*') |
    sturdy_apron('apron/.*') |
    sturdy_apron('effect/callframe/.*') |
    sturdy_apron('effect/store/RelationalStore.scala') |
    sturdy_apron('effect/store/RelationalStore.scala') |
    sturdy_apron('values/booleans/RelationalBoolBranching.scala') |
    sturdy_apron('values/booleans/RelationalBooleanOps.scala') |
    sturdy_apron('values/integer/RelationalIntegerOps.scala') |
    sturdy_apron('values/ordering/RelationalOrderingOps.scala')
]
tip4["language-independent"] = True
tip4["reuse"] = False

res = pandas.concat([tip1, tip2, tip3, tip4])

toTex(res)
print('\\def\\sumLanguageIndependentReuseFixpoint{'+str(fixpoint_language_independent['code'].sum())+' loc}')
print('\\def\\sumLanguageSpecificReuseFixpoint{'+str(cloc[sturdy_tip('abstractions/Fix.scala')]['code'].sum())+' loc}')
print('\\def\\sumLanguageSpecificNoReuseFixpoint{9 loc}')
# Out:
# \def\sumCode{6360 loc\xspace}
# \def\sumReuse{2642 loc\xspace}
# \def\sumNoReuse{3718 loc\xspace}
# \def\sumLanguageIndependent{5200 loc\xspace}
# \def\sumLanguageSpecific{1160 loc\xspace}
# \def\sumLanguageIndependentReuse{2369 loc\xspace}
# \def\sumLanguageIndependentNoReuse{2831 loc\xspace}
# \def\sumLanguageSpecificReuse{273 loc\xspace}
# \def\sumLanguageSpecificNoReuse{887 loc\xspace}
# \def\sumReuseOrLanguageIndependent{5473 loc\xspace}
# \def\percentCode{100.0\%\xspace}
# \def\percentReuse{41.5\%\xspace}
# \def\percentNoReuse{58.5\%\xspace}
# \def\percentLanguageIndependent{81.8\%\xspace}
# \def\percentLanguageSpecific{18.2\%\xspace}
# \def\percentLanguageIndependentReuse{37.2\%\xspace}
# \def\percentLanguageIndependentNoReuse{44.5\%\xspace}
# \def\percentLanguageSpecificReuse{4.3\%\xspace}
# \def\percentLanguageSpecificNoReuse{13.9\%\xspace}
# \def\percentReuseOrLanguageIndependent{86.1\%\xspace}
# \def\sumLanguageIndependentReuseFixpoint{717 loc}
# \def\sumLanguageSpecificReuseFixpoint{73 loc}
# \def\sumLanguageSpecificNoReuseFixpoint{9 loc}
# /tmp/ipykernel_82358/2015922807.py:11: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return cloc.filename.str.contains('sturdy-core/src/main/scala/sturdy/'+re, regex= True, na=False)

# %%
### Wasm
# Language-specific, reuse
wasm1 = cloc[
    sturdy_wasm('generic/') |
    sturdy_wasm('Interpreter.scala') |
    sturdy_wasm('Properties.scala') |
    sturdy_wasm('abstractions/ExceptionByTarget.scala') |
    sturdy_wasm('abstractions/ControlFlow.scala')
]
wasm1["language-independent"] = False
wasm1["reuse"] = True


# Language-specific, no reuse
wasm2 = cloc[
    sturdy_wasm('analyses/RelationalAnalysis.scala') |
    sturdy_wasm('abstractions/Relational(Addresses|I32Values|Memory|Types|Values).scala')
]
wasm2["language-independent"] = False
wasm2["reuse"] = False

# Language-independent, reuse
wasm3 = pandas.concat([common, tip4, cloc[
    sturdy_core('effect/allocation/(Allocator|AAllocatorFromContext).scala') |
    sturdy_core('effect/callframe/(CallFrame|DecidableCallFrame).scala') |
    sturdy_core('effect/bytememory/Memory.scala') |
    sturdy_core('effect/operandstack/(Decidable)?OperandStack.scala') |
    sturdy_core('effect/symboltable/(Decidable|Interval)?SymbolTable.scala') |
    sturdy_core('effect/except/(Joined)?Except.scala') |
    sturdy_core('effect/failure/(Failure|AFallible|CollectedFailures).scala') |
    sturdy_core('values/addresses/AddressOps.scala') |
    sturdy_core('values/booleans/(Lifted)?Boolean(Branching|Ops).scala') |
    sturdy_core('values/config/.*') |
    sturdy_core('values/convert/(Lifted|Transitive)?Convert.scala') |
    sturdy_core('values/exceptional/Exceptional(ByTarget)?.scala') |
    sturdy_core('values/functions/(Powerset|Lifted)?FunctionOps.scala') |
    sturdy_core('values/floating/(Lifted)?FloatOps.scala') |
    sturdy_core('values/integer/(Lifted)?IntegerOps.scala') |
    sturdy_core('values/ordering/(Lifted)?(Unsigned)?(Ordering|Eq)Ops.scala') |
    sturdy_core('values/references/(AbstractAddr|AbstractReference|(Lifted)?ReferenceOps).scala') |
    sturdy_core('values/types/BaseType.scala') |
    sturdy_core('values/Join.scala') |
    sturdy_core('values/Topped.scala')
]])
wasm3["language-independent"] = True
wasm3["reuse"] = True

# with pandas.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', 100):  # more options can be specified also
#     display(wasm3[['filename','code']].sort_values(by=['code']))

# Language-independent, no reuse
wasm4 = cloc[
    sturdy_core('effect/bytememory/AlignedMemory.scala') |
    sturdy_apron('effect/stack/RelationalStack.scala') |
    sturdy_apron('effect/symboltable/RelationalSymbolTable.scala') |
    sturdy_apron('values/booleans/RelationalBreakIfOps.scala') |
    sturdy_apron('values/convert/.*') |
    sturdy_apron('values/floating/.*')
]
wasm4["language-independent"] = True
wasm4["reuse"] = False

res = pandas.concat([wasm1, wasm2, wasm3, wasm4])

toTex(res)
# Out:
# /tmp/ipykernel_82358/2015922807.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return cloc.filename.str.contains('sturdy-wasm/src/main/scala/sturdy/language/wasm/'+re, regex= True, na=False)
# /tmp/ipykernel_82358/2015922807.py:11: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return cloc.filename.str.contains('sturdy-core/src/main/scala/sturdy/'+re, regex= True, na=False)
#                                                                                  filename  \
# 481  ../sturdy-core/src/main/scala/sturdy/values/ordering/LiftedUnsignedOrderingOps.scala
# 480          ../sturdy-core/src/main/scala/sturdy/values/ordering/LiftedOrderingOps.scala
# 479                ../sturdy-core/src/main/scala/sturdy/values/ordering/LiftedEqOps.scala
# 466                         ../sturdy-apron/src/main/scala/sturdy/apron/ApronScalar.scala
# 467                ../sturdy-core/src/main/scala/sturdy/effect/allocation/Allocator.scala
# 468                       ../sturdy-core/src/main/scala/sturdy/values/config/Config.scala
# 462       ../sturdy-core/src/main/scala/sturdy/values/references/LiftedReferenceOps.scala
# 460           ../sturdy-core/src/main/scala/sturdy/values/convert/TransitiveConvert.scala
# 459               ../sturdy-core/src/main/scala/sturdy/values/convert/LiftedConvert.scala
# 455                                  ../sturdy-core/src/main/scala/sturdy/data/Unit.scala
# 453         ../sturdy-core/src/main/scala/sturdy/values/functions/LiftedFunctionOps.scala
# 441    ../sturdy-core/src/main/scala/sturdy/effect/allocation/AAllocatorFromContext.scala
# 443           ../sturdy-core/src/main/scala/sturdy/values/booleans/LiftedBooleanOps.scala
# 427       ../sturdy-core/src/main/scala/sturdy/values/functions/PowersetFunctionOps.scala
# 420                      ../sturdy-core/src/main/scala/sturdy/values/ordering/EqOps.scala
# 419               ../sturdy-core/src/main/scala/sturdy/values/functions/FunctionOps.scala
# 417                     ../sturdy-core/src/main/scala/sturdy/effect/failure/Failure.scala
# 415                   ../sturdy-core/src/main/scala/sturdy/effect/bytememory/Memory.scala
# 403                            ../sturdy-apron/src/main/scala/sturdy/apron/ApronVar.scala
# 404                                ../sturdy-core/src/main/scala/sturdy/data/Option.scala
# 407     ../sturdy-core/src/main/scala/sturdy/values/booleans/LiftedBooleanBranching.scala
# 399                 ../sturdy-core/src/main/scala/sturdy/values/booleans/BooleanOps.scala
# 393        ../sturdy-core/src/main/scala/sturdy/values/ordering/UnsignedOrderingOps.scala
# 391                                  ../sturdy-core/src/main/scala/sturdy/data/Join.scala
# 379                 ../sturdy-core/src/main/scala/sturdy/effect/callframe/CallFrame.scala
# 381                                  ../sturdy-core/src/main/scala/sturdy/fix/State.scala
# 382                ../sturdy-core/src/main/scala/sturdy/values/ordering/OrderingOps.scala
# 375             ../sturdy-core/src/main/scala/sturdy/values/floating/LiftedFloatOps.scala
# 360             ../sturdy-core/src/main/scala/sturdy/values/references/ReferenceOps.scala
# 354                           ../sturdy-core/src/main/scala/sturdy/data/VectorClock.scala
# 347                ../sturdy-core/src/main/scala/sturdy/values/addresses/AddressOps.scala
# 345                            ../sturdy-core/src/main/scala/sturdy/fix/iter/Config.scala
# 339                                 ../sturdy-core/src/main/scala/sturdy/data/Tuple.scala
# 336                               ../sturdy-core/src/main/scala/sturdy/data/JEither.scala
# 335                       ../sturdy-core/src/main/scala/sturdy/effect/except/Except.scala
# 328                ../sturdy-core/src/main/scala/sturdy/values/config/NumericConfig.scala
# 325           ../sturdy-core/src/main/scala/sturdy/effect/failure/CollectedFailures.scala
# 320                     ../sturdy-core/src/main/scala/sturdy/values/convert/Convert.scala
# 319                    ../sturdy-core/src/main/scala/sturdy/fix/context/Sensitivity.scala
# 317                   ../sturdy-core/src/main/scala/sturdy/values/floating/FloatOps.scala
# 298      ../sturdy-apron/src/main/scala/sturdy/values/booleans/RelationalBooleanOps.scala
# 300             ../sturdy-core/src/main/scala/sturdy/values/references/AbstractAddr.scala
# 299             ../sturdy-core/src/main/scala/sturdy/effect/symboltable/SymbolTable.scala
# 281                      ../sturdy-apron/src/main/scala/sturdy/apron/RelationalExpr.scala
# 283                          ../sturdy-core/src/main/scala/sturdy/effect/EffectList.scala
# 284            ../sturdy-core/src/main/scala/sturdy/values/integer/LiftedIntegerOps.scala
# 277     ../sturdy-apron/src/main/scala/sturdy/values/ordering/RelationalOrderingOps.scala
# 268                             ../sturdy-core/src/main/scala/sturdy/fix/Contextual.scala
# 263                   ../sturdy-core/src/main/scala/sturdy/effect/ComputationJoiner.scala
# 264                                  ../sturdy-core/src/main/scala/sturdy/fix/Stack.scala
# 255           ../sturdy-core/src/main/scala/sturdy/values/booleans/BooleanBranching.scala
# 240                                  ../sturdy-core/src/main/scala/sturdy/data/List.scala
# 241                               ../sturdy-core/src/main/scala/sturdy/fix/Fixpoint.scala
# 230                   ../sturdy-core/src/main/scala/sturdy/effect/failure/AFallible.scala
# 223                              ../sturdy-core/src/main/scala/sturdy/effect/Effect.scala
# 221                      ../sturdy-core/src/main/scala/sturdy/values/types/BaseType.scala
# 212           ../sturdy-core/src/main/scala/sturdy/effect/operandstack/OperandStack.scala
# 213                         ../sturdy-core/src/main/scala/sturdy/fix/iter/Innermost.scala
# 208                         ../sturdy-core/src/main/scala/sturdy/fix/iter/Outermost.scala
# 201                                ../sturdy-core/src/main/scala/sturdy/values/Join.scala
# 200                           ../sturdy-core/src/main/scala/sturdy/fix/iter/Topmost.scala
# 198                              ../sturdy-core/src/main/scala/sturdy/values/Topped.scala
# 197                 ../sturdy-core/src/main/scala/sturdy/effect/except/JoinedExcept.scala
# 192                           ../sturdy-core/src/main/scala/sturdy/effect/TrySturdy.scala
# 181                  ../sturdy-core/src/main/scala/sturdy/values/integer/IntegerOps.scala
# 180                            ../sturdy-core/src/main/scala/sturdy/fix/Combinators.scala
# 165                       ../sturdy-apron/src/main/scala/sturdy/apron/ApronInterval.scala
# 138        ../sturdy-core/src/main/scala/sturdy/effect/callframe/DecidableCallFrame.scala
# 139        ../sturdy-core/src/main/scala/sturdy/values/references/AbstractReference.scala
# 135     ../sturdy-core/src/main/scala/sturdy/effect/symboltable/IntervalSymbolTable.scala
# 129  ../sturdy-core/src/main/scala/sturdy/effect/operandstack/DecidableOperandStack.scala
# 128                  ../sturdy-apron/src/main/scala/sturdy/apron/ApronExprConverter.scala
# 123                                   ../sturdy-core/src/main/scala/sturdy/data/Map.scala
# 118                           ../sturdy-apron/src/main/scala/sturdy/apron/ApronType.scala
# 114                        ../sturdy-apron/src/main/scala/sturdy/apron/ApronLattice.scala
# 115                         ../sturdy-core/src/main/scala/sturdy/effect/EffectStack.scala
# 100    ../sturdy-core/src/main/scala/sturdy/effect/symboltable/DecidableSymbolTable.scala
# 89                        ../sturdy-apron/src/main/scala/sturdy/apron/FloatInterval.scala
# 86                                ../sturdy-core/src/main/scala/sturdy/data/JOption.scala
# 70       ../sturdy-apron/src/main/scala/sturdy/effect/callframe/RelationalCallFrame.scala
# 47                           ../sturdy-core/src/main/scala/sturdy/fix/StackedStates.scala
# 37        ../sturdy-apron/src/main/scala/sturdy/values/integer/RelationalIntegerOps.scala
# 20                            ../sturdy-apron/src/main/scala/sturdy/apron/ApronExpr.scala
# 16                           ../sturdy-apron/src/main/scala/sturdy/apron/ApronState.scala
# 10               ../sturdy-apron/src/main/scala/sturdy/effect/store/RelationalStore.scala
#
#      code
# 481     4
# 480     4
# 479     4
# 466     5
# 467     5
# 468     5
# 462     6
# 460     6
# 459     6
# 455     6
# 453     7
# 441     8
# 443     8
# 427    11
# 420    13
# 419    13
# 417    13
# 415    13
# 403    14
# 404    14
# 407    14
# 399    15
# 393    16
# 391    16
# 379    18
# 381    18
# 382    18
# 375    19
# 360    22
# 354    23
# 347    24
# 345    24
# 339    25
# 336    26
# 335    27
# 328    28
# 325    29
# 320    30
# 319    30
# 317    32
# 298    36
# 300    36
# 299    36
# 281    41
# 283    41
# 284    41
# 277    42
# 268    44
# 263    45
# 264    45
# 255    49
# 240    52
# 241    52
# 230    56
# 223    58
# 221    59
# 212    62
# 213    62
# 208    64
# 201    67
# 200    67
# 198    68
# 197    69
# 192    71
# 181    76
# 180    76
# 165    85
# 138   104
# 139   104
# 135   105
# 129   113
# 128   115
# 123   119
# 118   120
# 114   122
# 115   122
# 100   134
# 89    145
# 86    151
# 70    178
# 47    235
# 37    272
# 20    417
# 16    505
# 10    734
# \def\sumCode{11389 loc\xspace}
# \def\sumReuse{8228 loc\xspace}
# \def\sumNoReuse{3161 loc\xspace}
# \def\sumLanguageIndependent{7049 loc\xspace}
# \def\sumLanguageSpecific{4340 loc\xspace}
# \def\sumLanguageIndependentReuse{5914 loc\xspace}
# \def\sumLanguageIndependentNoReuse{1135 loc\xspace}
# \def\sumLanguageSpecificReuse{2314 loc\xspace}
# \def\sumLanguageSpecificNoReuse{2026 loc\xspace}
# \def\sumReuseOrLanguageIndependent{9363 loc\xspace}
# \def\percentCode{100.0\%\xspace}
# \def\percentReuse{72.2\%\xspace}
# \def\percentNoReuse{27.8\%\xspace}
# \def\percentLanguageIndependent{61.9\%\xspace}
# \def\percentLanguageSpecific{38.1\%\xspace}
# \def\percentLanguageIndependentReuse{51.9\%\xspace}
# \def\percentLanguageIndependentNoReuse{10.0\%\xspace}
# \def\percentLanguageSpecificReuse{20.3\%\xspace}
# \def\percentLanguageSpecificNoReuse{17.8\%\xspace}
# \def\percentReuseOrLanguageIndependent{82.2\%\xspace}
